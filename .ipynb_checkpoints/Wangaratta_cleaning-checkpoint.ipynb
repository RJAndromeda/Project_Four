# %%
import pandas as pd

import numpy as np

# %%
df1 = pd.read_csv("Wang\IDCJDW3081.202112.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df2 = pd.read_csv("Wang\IDCJDW3081.202111.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df3 = pd.read_csv("Wang\IDCJDW3081.202110.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df4 = pd.read_csv("Wang\IDCJDW3081.202109.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df5 = pd.read_csv("Wang\IDCJDW3081.202108.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df6 = pd.read_csv("Wang\IDCJDW3081.202107.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df7 = pd.read_csv("Wang\IDCJDW3081.202106.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df8 = pd.read_csv("Wang\IDCJDW3081.202105.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df9 = pd.read_csv("Wang\IDCJDW3081.202104.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df10 = pd.read_csv("Wang\IDCJDW3081.202103.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df11 = pd.read_csv("Wang\IDCJDW3081.202102.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df12 = pd.read_csv("Wang\IDCJDW3081.202101.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df13 = pd.read_csv("Wang\IDCJDW3081.202012.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df14 = pd.read_csv("Wang\IDCJDW3081.202011.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df15 = pd.read_csv("Wang\IDCJDW3081.202010.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df16 = pd.read_csv("Wang\IDCJDW3081.202009.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df17 = pd.read_csv("Wang\IDCJDW3081.202008.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df18 = pd.read_csv("Wang\IDCJDW3081.202007.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df19 = pd.read_csv("Wang\IDCJDW3081.202006.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df20 = pd.read_csv("Wang\IDCJDW3081.202005.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df21 = pd.read_csv("Wang\IDCJDW3081.202004.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df22 = pd.read_csv("Wang\IDCJDW3081.202003.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df23 = pd.read_csv("Wang\IDCJDW3081.201908.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df24 = pd.read_csv("Wang\IDCJDW3081.201907.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df25 = pd.read_csv("Wang\IDCJDW3081.201906.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df26 = pd.read_csv("Wang\IDCJDW3081.201905.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df27 = pd.read_csv("Wang\IDCJDW3081.201904.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df28 = pd.read_csv("Wang\IDCJDW3081.201903.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df29 = pd.read_csv("Wang\IDCJDW3081.201902.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df30 = pd.read_csv("Wang\IDCJDW3081.201901.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df31 = pd.read_csv("Wang\IDCJDW3081.201812.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df32 = pd.read_csv("Wang\IDCJDW3081.201811.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df33 = pd.read_csv("Wang\IDCJDW3081.201810.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df34 = pd.read_csv("Wang\IDCJDW3081.201809.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df35 = pd.read_csv("Wang\IDCJDW3081.201808.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df36 = pd.read_csv("Wang\IDCJDW3081.201807.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df37 = pd.read_csv("Wang\IDCJDW3081.201806.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df38 = pd.read_csv("Wang\IDCJDW3081.201805.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df39 = pd.read_csv("Wang\IDCJDW3081.201804.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df40 = pd.read_csv("Wang\IDCJDW3081.201803.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df41 = pd.read_csv("Wang\IDCJDW3081.201802.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df42 = pd.read_csv("Wang\IDCJDW3081.201801.csv", skiprows=5, nrows=38, encoding = "windows-1252")

# %%
df43 = pd.read_csv("Wang\Wangaratta_missing.csv")

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10,\
          df11, df12, df13, df14, df15, df16, df17, df18, df19,\
          df20, df21, df22, df23, df24, df25, df26, df27, df28, \
          df29, df30, df31, df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,df42,df43]
result = pd.concat(frames)

# %%
result.tail()
# Out:
#     Unnamed: 0        Date  Minimum temperature (°C)  \
# 55         NaN  27/01/2020                      13.9
# 56         NaN  28/01/2020                      13.0
# 57         NaN  29/01/2020                      12.7
# 58         NaN  30/01/2020                      13.6
# 59         NaN  31/01/2020                      18.4
#
#     Maximum temperature (°C)  Rainfall (mm)  Evaporation (mm)  \
# 55                      35.4            0.0               NaN
# 56                      34.6            0.0               NaN
# 57                      37.2            0.0               NaN
# 58                      39.5            0.0               NaN
# 59                      45.6            0.0               NaN
#
#     Sunshine (hours) Direction of maximum wind gust   \
# 55               NaN                             WSW
# 56               NaN                              SW
# 57               NaN                             WSW
# ...

# %%
# drop unneccessary columns with too many NAN values
clean_Wangaratta = pd.DataFrame(result.drop(columns=['Unnamed: 0','Evaporation (mm)', 'Sunshine (hours)','9am cloud amount (oktas)', '3pm cloud amount (oktas)', '9am MSL pressure (hPa)', '3pm MSL pressure (hPa)', '3pm relative humidity (%)', '9am relative humidity (%)' ]))

# %%
clean_Wangaratta.head(10)
# Out:
#          Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-12-1                      15.3                      31.2
# 1   2021-12-2                      13.4                      33.2
# 2   2021-12-3                      16.2                      29.5
# 3   2021-12-4                      11.5                      23.6
# 4   2021-12-5                       9.5                      26.9
# 5   2021-12-6                      13.2                      25.7
# 6   2021-12-7                      14.2                      28.8
# 7   2021-12-8                       8.8                      21.9
# 8   2021-12-9                       7.5                      19.8
# 9  2021-12-10                      11.7                       NaN
#
#    Rainfall (mm) Direction of maximum wind gust   \
# 0            0.0                             SSW
# 1            0.0                              SW
# 2            1.4                               W
# ...

# %%
clean_Wangaratta.dtypes
# Out:
# Date                                  object
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Direction of maximum wind gust        object
# Speed of maximum wind gust (km/h)    float64
# Time of maximum wind gust             object
# 9am Temperature (°C)                 float64
# 9am wind direction                    object
# 9am wind speed (km/h)                 object
# 3pm Temperature (°C)                 float64
# 3pm wind direction                    object
# 3pm wind speed (km/h)                 object
# dtype: object

# %%
clean_Wangaratta['station_id']= 82138

# %%
# change 'calm' to numeric 0 in wind speed column
clean_Wangaratta['9am wind speed (km/h)'].replace("Calm", 0, inplace=True)

# %%
clean_Wangaratta['3pm wind speed (km/h)'].replace("Calm", 0, inplace=True)

# %%
clean_Wangaratta['Speed of maximum wind gust (km/h)'].replace("Calm", 0, inplace=True)

# %%
clean_Wangaratta['9am wind speed (km/h)'].replace(np.nan, 0, inplace=True)

# %%
clean_Wangaratta['3pm wind speed (km/h)'].replace(np.nan, 0, inplace=True)

# %%
clean_Wangaratta['Speed of maximum wind gust (km/h)'].replace(np.nan, 0, inplace=True)

# %%
clean_Wangaratta.head(20)
# Out:
#          Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2021-12-1                      15.3                      31.2
# 1   2021-12-2                      13.4                      33.2
# 2   2021-12-3                      16.2                      29.5
# 3   2021-12-4                      11.5                      23.6
# 4   2021-12-5                       9.5                      26.9
# 5   2021-12-6                      13.2                      25.7
# 6   2021-12-7                      14.2                      28.8
# 7   2021-12-8                       8.8                      21.9
# 8   2021-12-9                       7.5                      19.8
# 9  2021-12-10                      11.7                       NaN
# 0   2021-11-1                       3.2                      23.4
# 1   2021-11-2                       5.6                      28.0
# 2   2021-11-3                      12.1                      25.9
# ...

# %%
clean_Wangaratta['Speed of maximum wind gust (km/h)'].replace('NaN', 0, inplace=True)

# %%
clean_Wangaratta['9am wind speed (km/h)'].replace('NaN', 0, inplace=True)

# %%
clean_Wangaratta['3pm wind speed (km/h)'].replace('NaN', 0, inplace=True)

# %%
clean_Wangaratta['9am wind direction'].replace(np.nan, "None", inplace=True)

# %%
clean_Wangaratta['3pm wind direction'].replace(np.nan, "None", inplace=True)

# %%
clean_Wangaratta['Direction of maximum wind gust '].replace(np.nan, "None", inplace=True)

# %%
clean_Wangaratta.isnull().values.sum()
# Out:
# 47

# %%
clean_Wangaratta['9am wind direction'].replace(0, "None", inplace=True)

# %%
clean_Wangaratta['9am wind direction'].replace(" ", "None", inplace=True)

# %%
clean_Wangaratta['9am wind direction'].replace("Calm", "None", inplace=True)

# %%
# I can be blind sometimes. Check for spaces, always. Keeping in for posterity
print(clean_Wangaratta['9am wind direction'].unique())
# Out:
# ['SE' 'ESE' 'SSW' 'WSW' 'NE' 'S' 'SSE' 'NNE' 'N' 'E' 'SW' 'WNW' 'None'
#  'ENE' 'W' 'NW' 'NNW']

# %%
# get rid of NANs in some of the columns
clean_Wangaratta['Rainfall (mm)'] = clean_Wangaratta['Rainfall (mm)'].fillna(0)

# %%
# Other columns
clean_Wangaratta['9am wind direction'].replace(" ", "None", inplace=True)

# %%
clean_Wangaratta['3pm wind direction'].replace(" ", "None", inplace=True)

# %%
clean_Wangaratta['3pm wind direction'].replace("nan", "None", inplace=True)

# %%
clean_Wangaratta['9am wind direction'].replace("nan", "None", inplace=True)

# %%
clean_Wangaratta['3pm wind direction'].replace("NaN", "None", inplace=True)

# %%
clean_Wangaratta['9am wind direction'].replace("NaN", "None", inplace=True)

# %%
clean_Wangaratta.isnull().values.sum()
# Out:
# 40

# %%
clean_Wangaratta['3pm Temperature (°C)'] = pd.to_numeric(clean_Wangaratta['3pm Temperature (°C)'], errors='coerce')
clean_Wangaratta['3pm Temperature (°C)'].interpolate(inplace=True)
clean_Wangaratta['3pm Temperature (°C)'] = clean_Wangaratta['3pm Temperature (°C)'].round(1)

# %%
clean_Wangaratta['9am Temperature (°C)'] = pd.to_numeric(clean_Wangaratta['3pm Temperature (°C)'], errors='coerce')
clean_Wangaratta['9am Temperature (°C)'].interpolate(inplace=True)
clean_Wangaratta['9am Temperature (°C)'] = clean_Wangaratta['9am Temperature (°C)'].round(1)

# %%
clean_Wangaratta['Minimum temperature (°C)'] = pd.to_numeric(clean_Wangaratta['Minimum temperature (°C)'], errors='coerce')
clean_Wangaratta['Minimum temperature (°C)'].interpolate(inplace=True)
clean_Wangaratta['Minimum temperature (°C)'] = clean_Wangaratta['Minimum temperature (°C)'].round(1)

# %%
clean_Wangaratta['Maximum temperature (°C)'] = pd.to_numeric(clean_Wangaratta['Maximum temperature (°C)'], errors='coerce')
clean_Wangaratta['Maximum temperature (°C)'].interpolate(inplace=True)
clean_Wangaratta['Maximum temperature (°C)'] = clean_Wangaratta['Maximum temperature (°C)'].round(1)

# %%
clean_Wangaratta['Rainfall (mm)'] = pd.to_numeric(clean_Wangaratta['Rainfall (mm)'], errors='coerce')
clean_Wangaratta['Rainfall (mm)'].interpolate(inplace=True)
clean_Wangaratta['Rainfall (mm)'] = clean_Wangaratta['Rainfall (mm)'].round(1)

# %%
clean_Wangaratta
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0    2021-12-1                      15.3                      31.2
# 1    2021-12-2                      13.4                      33.2
# 2    2021-12-3                      16.2                      29.5
# 3    2021-12-4                      11.5                      23.6
# 4    2021-12-5                       9.5                      26.9
# ..         ...                       ...                       ...
# 55  27/01/2020                      13.9                      35.4
# 56  28/01/2020                      13.0                      34.6
# 57  29/01/2020                      12.7                      37.2
# 58  30/01/2020                      13.6                      39.5
# 59  31/01/2020                      18.4                      45.6
#
#     Rainfall (mm) Direction of maximum wind gust   \
# 0             0.0                             SSW
# 1             0.0                              SW
# ...

# %%
clean_Wangaratta.isnull().values.sum()
# Out:
# 13

# %%
# change those columns with no times to 00:00 (not enough to be statistically relevant)
clean_Wangaratta['Time of maximum wind gust'].replace(np.nan, "00:00", inplace=True)

# %%
# no longer necessary, but leaving in for next run.
rows_with_nan = clean_Wangaratta[clean_Wangaratta.isna().any(axis=1)]

# Print the rows with NaN values
print(rows_with_nan)
# Out:
# Empty DataFrame
# Columns: [Date, Minimum temperature (°C), Maximum temperature (°C), Rainfall (mm), Direction of maximum wind gust , Speed of maximum wind gust (km/h), Time of maximum wind gust, 9am Temperature (°C), 9am wind direction, 9am wind speed (km/h), 3pm Temperature (°C), 3pm wind direction, 3pm wind speed (km/h), station_id]
# Index: []

# %%
clean_Wangaratta.isnull().values.sum()
# Out:
# 0

# %%
# clean date column
clean_Wangaratta['Date']= pd.to_datetime(clean_Wangaratta['Date'], dayfirst=True)

# %%
clean_Wangaratta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 59
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               1302 non-null   datetime64[ns]
#  1   Minimum temperature (°C)           1302 non-null   float64
#  2   Maximum temperature (°C)           1302 non-null   float64
#  3   Rainfall (mm)                      1302 non-null   float64
#  4   Direction of maximum wind gust     1302 non-null   object
#  5   Speed of maximum wind gust (km/h)  1302 non-null   float64
#  6   Time of maximum wind gust          1302 non-null   object
#  7   9am Temperature (°C)               1302 non-null   float64
#  8   9am wind direction                 1302 non-null   object
#  9   9am wind speed (km/h)              1302 non-null   object
#  10  3pm Temperature (°C)               1302 non-null   float64
# ...

# %%
# Change data column types for time and date fields, also for km/h, now 'calm' has been replaced with 0.

clean_Wangaratta[["9am wind speed (km/h)", "3pm wind speed (km/h)"]] = clean_Wangaratta[["9am wind speed (km/h)", "3pm wind speed (km/h)"]].apply(pd.to_numeric)

# %%
clean_Wangaratta.dtypes
# Out:
# Date                                 datetime64[ns]
# Minimum temperature (°C)                    float64
# Maximum temperature (°C)                    float64
# Rainfall (mm)                               float64
# Direction of maximum wind gust               object
# Speed of maximum wind gust (km/h)           float64
# Time of maximum wind gust                    object
# 9am Temperature (°C)                        float64
# 9am wind direction                           object
# 9am wind speed (km/h)                       float64
# 3pm Temperature (°C)                        float64
# 3pm wind direction                           object
# 3pm wind speed (km/h)                       float64
# station_id                                    int64
# dtype: object

# %%
clean_Wangaratta.rename(columns={"Date": "Date", "Minimum temperature (°C)": "Wang_Minimum temperature (°C)", "Maximum temperature (°C)":"Wang_Maximum temperature (°C)", "Rainfall (mm)":"Wang_Rainfall (mm)", "Direction of maximum wind gust ":"Wang_Direction of maximum wind gust", "Speed of maximum wind gust (km/h)":"Wang_Speed of maximum wind gust (km/h)","Time of maximum wind gust":"Wang_Time of maximum wind gust","9am Temperature (°C)":"Wang_9am Temperature (°C)","9am Temperature (°C)":"Wang_9am Temperature (°C)"})
# Out:
#          Date  Wang_Minimum temperature (°C)  Wang_Maximum temperature (°C)  \
# 0  2021-12-01                           15.3                           31.2
# 1  2021-12-02                           13.4                           33.2
# 2  2021-12-03                           16.2                           29.5
# 3  2021-12-04                           11.5                           23.6
# 4  2021-12-05                            9.5                           26.9
# ..        ...                            ...                            ...
# 55 2020-01-27                           13.9                           35.4
# 56 2020-01-28                           13.0                           34.6
# 57 2020-01-29                           12.7                           37.2
# 58 2020-01-30                           13.6                           39.5
# 59 2020-01-31                           18.4                           45.6
#
# ...

# %%
clean_Wangaratta_slim = clean_Wangaratta[['Date','Minimum temperature (°C)','Maximum temperature (°C)','Direction of maximum wind gust ','Speed of maximum wind gust (km/h)']].copy()

# %%
clean_Wangaratta.to_csv('clean_Wangaratta.csv', sep=',', index=False)

# %%
clean_Wangaratta_slim = clean_Wangaratta_slim.rename(columns={"Minimum temperature (°C)":'Wang_Minimum temperature (°C)',"Maximum temperature (°C)":"Wang_Maximum temperature (°C)","Direction of maximum wind gust ":"Wang_Direction of maximum wind gust","Speed of maximum wind gust (km/h)":"Wang_Speed of maximum wind gust (km/h)"})

# %%
clean_Wangaratta_slim.head(50)
# Out:
#          Date  Wang_Minimum temperature (°C)  Wang_Maximum temperature (°C)  \
# 0  2021-12-01                           15.3                           31.2
# 1  2021-12-02                           13.4                           33.2
# 2  2021-12-03                           16.2                           29.5
# 3  2021-12-04                           11.5                           23.6
# 4  2021-12-05                            9.5                           26.9
# 5  2021-12-06                           13.2                           25.7
# 6  2021-12-07                           14.2                           28.8
# 7  2021-12-08                            8.8                           21.9
# 8  2021-12-09                            7.5                           19.8
# 9  2021-12-10                           11.7                           21.6
# 0  2021-11-01                            3.2                           23.4
# ...

# %%
clean_Wangaratta_slim.to_csv('clean_Wangaratta_slim.csv', sep=',', index=False)
