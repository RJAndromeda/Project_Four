# %%
import pandas as pd

import numpy as np

# %%
df1 = pd.read_csv('Ballarat\IDCJDW3005.202207.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df2 = pd.read_csv('Ballarat\IDCJDW3005.202206.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df3 = pd.read_csv('Ballarat\IDCJDW3005.202205.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df4 = pd.read_csv('Ballarat\IDCJDW3005.202204.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df5 = pd.read_csv('Ballarat\IDCJDW3005.202203.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df6 = pd.read_csv('Ballarat\IDCJDW3005.202202.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df7 = pd.read_csv('Ballarat\IDCJDW3005.202201.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df8 = pd.read_csv('Ballarat\IDCJDW3005.202112.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df9 = pd.read_csv('Ballarat\IDCJDW3005.202111.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df10 = pd.read_csv('Ballarat\IDCJDW3005.202110.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df11 = pd.read_csv('Ballarat\IDCJDW3005.202109.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df12 = pd.read_csv('Ballarat\IDCJDW3005.202108.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df13 = pd.read_csv('Ballarat\IDCJDW3005.202107.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df14 = pd.read_csv('Ballarat\IDCJDW3005.202106.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df15 = pd.read_csv('Ballarat\IDCJDW3005.202105.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df16 = pd.read_csv('Ballarat\IDCJDW3005.202104.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df17 = pd.read_csv('Ballarat\IDCJDW3005.202103.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df18 = pd.read_csv('Ballarat\IDCJDW3005.202102.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df19 = pd.read_csv('Ballarat\IDCJDW3005.202101.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df20 = pd.read_csv('Ballarat\IDCJDW3005.202012.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df21 = pd.read_csv('Ballarat\IDCJDW3005.202011.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df21a = pd.read_csv('Ballarat\IDCJDW3005.202010.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df21b = pd.read_csv('Ballarat\IDCJDW3005.202009.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df22 = pd.read_csv('Ballarat\IDCJDW3005.202008.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df23 = pd.read_csv('Ballarat\IDCJDW3005.202007.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df24 = pd.read_csv('Ballarat\IDCJDW3005.202006.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df25 = pd.read_csv('Ballarat\IDCJDW3005.202005.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df26 = pd.read_csv('Ballarat\IDCJDW3005.202004.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df27 = pd.read_csv('Ballarat\IDCJDW3005.202003.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df28 = pd.read_csv('Ballarat\IDCJDW3005.202002.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df29 = pd.read_csv('Ballarat\IDCJDW3005.202001.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df30 = pd.read_csv('Ballarat\IDCJDW3005.201912.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df31 = pd.read_csv('Ballarat\IDCJDW3005.201911.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df32 = pd.read_csv('Ballarat\IDCJDW3005.201910.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df33 = pd.read_csv('Ballarat\IDCJDW3005.201909.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df34 = pd.read_csv('Ballarat\IDCJDW3005.201908.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df35 = pd.read_csv('Ballarat\IDCJDW3005.201907.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df36 = pd.read_csv('Ballarat\IDCJDW3005.201906.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df37 = pd.read_csv('Ballarat\IDCJDW3005.201905.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df38 = pd.read_csv('Ballarat\IDCJDW3005.201904.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df39 = pd.read_csv('Ballarat\IDCJDW3005.201903.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df40 = pd.read_csv('Ballarat\IDCJDW3005.201902.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
df41 = pd.read_csv('Ballarat\IDCJDW3005.201901.csv', skiprows=6, nrows=38, encoding = "windows-1252")

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18,\
          df19, df20, df21, df21a, df21b, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33,\
          df34, df35, df36, df37, df38, df39, df40, df41]
result = pd.concat(frames)

# %%
result.head()
# Out:
#    Unnamed: 0       Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0         NaN  2022-07-1                       4.8                       9.5
# 1         NaN  2022-07-2                       1.2                      10.0
# 2         NaN  2022-07-3                       4.8                      10.2
# 3         NaN  2022-07-4                       4.9                      11.5
# 4         NaN  2022-07-5                       5.9                      11.9
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.2               NaN               NaN
# 1            0.2               NaN               NaN
# 2            0.0               NaN               NaN
# 3            0.0               NaN               NaN
# 4            0.2               NaN               NaN
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             SSE                               35.0
# ...

# %%
# drop unneccessary columns with too many NAN values
result.drop(columns=['Unnamed: 0', 'Evaporation (mm)', 'Sunshine (hours)', '9am cloud amount (oktas)','3pm cloud amount (oktas)']).tail()
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 26  2019-01-27                      12.0                      26.2
# 27  2019-01-28                      11.2                      31.7
# 28  2019-01-29                      11.0                      34.0
# 29  2019-01-30                      11.7                      36.7
# 30  2019-01-31                      11.9                      21.2
#
#     Rainfall (mm) Direction of maximum wind gust   \
# 26            0.0                               W
# 27            0.0                               N
# 28            0.0                             NNW
# 29            0.0                              NW
# 30            0.2                             SSW
#
#     Speed of maximum wind gust (km/h) Time of maximum wind gust  \
# 26                               50.0                     14:42
# 27                               44.0                     14:53
# ...

# %%
clean_Ballarat = pd.DataFrame(result.drop(columns=['Unnamed: 0','Evaporation (mm)', 'Sunshine (hours)','9am cloud amount (oktas)', '3pm cloud amount (oktas)', '9am MSL pressure (hPa)', '3pm MSL pressure (hPa)', '3pm relative humidity (%)', '9am relative humidity (%)' ]))

# %%
clean_Ballarat.head(10)
# Out:
#          Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0   2022-07-1                       4.8                       9.5
# 1   2022-07-2                       1.2                      10.0
# 2   2022-07-3                       4.8                      10.2
# 3   2022-07-4                       4.9                      11.5
# 4   2022-07-5                       5.9                      11.9
# 5   2022-07-6                      -2.4                      12.9
# 6   2022-07-7                       0.0                      10.7
# 7   2022-07-8                       4.9                      10.1
# 8   2022-07-9                       4.9                      10.4
# 9  2022-07-10                       2.8                      12.8
#
#    Rainfall (mm) Direction of maximum wind gust   \
# 0            0.2                             SSE
# 1            0.2                              SE
# 2            0.0                              SE
# ...

# %%
clean_Ballarat.dtypes
# Out:
# Date                                  object
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Direction of maximum wind gust        object
# Speed of maximum wind gust (km/h)    float64
# Time of maximum wind gust             object
# 9am Temperature (°C)                 float64
# 9am wind direction                    object
# 9am wind speed (km/h)                 object
# 3pm Temperature (°C)                 float64
# 3pm wind direction                    object
# 3pm wind speed (km/h)                 object
# dtype: object

# %%
clean_Ballarat['station_id']= 89002

# %%
# change 'calm' to numeric 0 in wind speed column
clean_Ballarat['9am wind speed (km/h)'].replace("Calm", 0, inplace=True)

# %%
clean_Ballarat['3pm wind speed (km/h)'].replace("Calm", 0, inplace=True)

# %%
clean_Ballarat['Speed of maximum wind gust (km/h)'].replace("Calm", 0, inplace=True)

# %%
clean_Ballarat['9am wind speed (km/h)'].replace(np.nan, 0, inplace=True)

# %%
clean_Ballarat['3pm wind speed (km/h)'].replace(np.nan, 0, inplace=True)

# %%
clean_Ballarat['Speed of maximum wind gust (km/h)'].replace(np.nan, 0, inplace=True)

# %%
clean_Ballarat.head(20)
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0    2022-07-1                       4.8                       9.5
# 1    2022-07-2                       1.2                      10.0
# 2    2022-07-3                       4.8                      10.2
# 3    2022-07-4                       4.9                      11.5
# 4    2022-07-5                       5.9                      11.9
# 5    2022-07-6                      -2.4                      12.9
# 6    2022-07-7                       0.0                      10.7
# 7    2022-07-8                       4.9                      10.1
# 8    2022-07-9                       4.9                      10.4
# 9   2022-07-10                       2.8                      12.8
# 10  2022-07-11                       2.9                       8.9
# 11  2022-07-12                       5.2                      10.7
# 12  2022-07-13                       0.0                      10.3
# ...

# %%
clean_Ballarat['Speed of maximum wind gust (km/h)'].replace('NaN', 0, inplace=True)

# %%
clean_Ballarat['9am wind speed (km/h)'].replace('NaN', 0, inplace=True)

# %%
clean_Ballarat['3pm wind speed (km/h)'].replace('NaN', 0, inplace=True)

# %%
clean_Ballarat['9am wind direction'].replace(np.nan, "None", inplace=True)

# %%
clean_Ballarat['3pm wind direction'].replace(np.nan, "None", inplace=True)

# %%
clean_Ballarat['Direction of maximum wind gust '].replace(np.nan, "None", inplace=True)

# %%
clean_Ballarat.isnull().values.sum()
# Out:
# 19

# %%
# no longer necessary, but leaving in for next run.
rows_with_nan = clean_Ballarat[clean_Ballarat.isna().any(axis=1)]

# Print the rows with NaN values
print(rows_with_nan)
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 9   2022-05-10                       3.6                       NaN
# 10  2022-03-11                       8.5                      19.8
# 11  2022-03-12                       9.0                      24.2
# 5    2021-04-6                      10.3                      20.2
# 29  2021-03-30                       5.4                       NaN
# 30  2021-03-31                       7.4                      24.0
# 22  2020-08-23                       2.9                       NaN
# 4    2020-04-5                       4.7                      14.4
# 17  2019-12-18                      12.4                       NaN
# 27  2019-12-28                      17.5                       NaN
# 5    2019-11-6                       6.7                       NaN
# 6    2019-10-7                       6.7                      14.4
# 7    2019-10-8                       5.0                      11.2
# ...

# %%
# clean_Ballarat['9am wind direction'].replace(0, "None", inplace=True)

# %%
# clean_Ballarat['9am wind direction'].replace(" ", "None", inplace=True)

# %%
# clean_Ballarat['9am wind direction'] = clean_Ballarat['9am wind direction'].fillna(0)

# %%
# I can be blind sometimes. Check for spaces, always. Keeping in for posterity
print(clean_Ballarat['9am wind direction'].unique())
# Out:
# ['S' 'SSE' 'SE' 'N' 'WSW' 'SW' 'E' 'SSW' 'NNW' ' ' 'NNE' 'ENE' 'W' 'WNW'
#  'NE' 'ESE' 'NW']

# %%
# print(clean_Ferny_Creek['9am MSL pressure (hPa)'].unique())

# %%
# get rid of NANs in some of the columns
clean_Ballarat['Rainfall (mm)'] = clean_Ballarat['Rainfall (mm)'].fillna(0)

# %%
# no longer necessary, but leaving in for next run.
rows_with_nan = clean_Ballarat[clean_Ballarat.isna().any(axis=1)]

# Print the rows with NaN values
print(rows_with_nan)
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 9   2022-05-10                       3.6                       NaN
# 10  2022-03-11                       8.5                      19.8
# 5    2021-04-6                      10.3                      20.2
# 29  2021-03-30                       5.4                       NaN
# 30  2021-03-31                       7.4                      24.0
# 22  2020-08-23                       2.9                       NaN
# 4    2020-04-5                       4.7                      14.4
# 17  2019-12-18                      12.4                       NaN
# 27  2019-12-28                      17.5                       NaN
# 5    2019-11-6                       6.7                       NaN
# 6    2019-10-7                       6.7                      14.4
# 7    2019-10-8                       5.0                      11.2
# 3    2019-06-4                       4.6                       8.3
# ...

# %%
# Other columns
# clean_Ballarat['9am wind direction'].replace(" ", "None", inplace=True)

# %%
# clean_Ballarat['3pm wind direction'].replace(" ", "None", inplace=True)

# %%
# clean_Ballarat['3pm wind direction'].replace("nan", "None", inplace=True)

# %%
# clean_Ballarat['9am wind direction'].replace("nan", "None", inplace=True)

# %%
# clean_Ballarat['3pm wind direction'].replace("NaN", "None", inplace=True)

# %%
# clean_Ballarat['9am wind direction'].replace("NaN", "None", inplace=True)

# %%
clean_Ballarat.isnull().values.sum()
# Out:
# 16

# %%
clean_Ballarat['Rainfall (mm)'] = pd.to_numeric(clean_Ballarat['Rainfall (mm)'], errors='coerce')
clean_Ballarat['Rainfall (mm)'].interpolate(inplace=True)
clean_Ballarat['Rainfall (mm)'] = clean_Ballarat['Rainfall (mm)'].round(1)

# %%
# clean_Ballarat['Minimum temperature (°C)'] = pd.to_numeric(clean_Ballarat['Minimum temperature (°C)'], errors='coerce')
# clean_Ballarat['Minimum temperature (°C)'].interpolate(inplace=True)

# %%
clean_Ballarat['Maximum temperature (°C)'] = pd.to_numeric(clean_Ballarat['Maximum temperature (°C)'], errors='coerce')
clean_Ballarat['Maximum temperature (°C)'].interpolate(inplace=True)
clean_Ballarat['Maximum temperature (°C)'] = clean_Ballarat['Maximum temperature (°C)'].round(1)

# %%
# change those columns with no times to 00:00 (not enough to be statistically relevant)
clean_Ballarat['Time of maximum wind gust'].replace(np.nan, "00:00", inplace=True)

# %%
clean_Ballarat.isnull().values.sum()
# Out:
# 0

# %%
# # no longer necessary, but leaving in for next run.
# rows_with_nan = clean_Ballarat[clean_Ballarat.isna().any(axis=1)]

# # Print the rows with NaN values
# print(rows_with_nan)

# %%
# clean_Ballarat['Direction of maximum wind gust '].replace(" ", "None", inplace=True)

# %%
# clean_Ballarat['Direction of maximum wind gust '].replace("NaN", "None", inplace=True)

# %%
# clean_Ballarat['Direction of maximum wind gust '].replace(np.nan, "None", inplace=True)

# %%
# clean_Ballarat['3pm wind direction'].replace(" ", "None", inplace=True)

# %%
clean_Ballarat.dtypes
# Out:
# Date                                  object
# Minimum temperature (°C)             float64
# Maximum temperature (°C)             float64
# Rainfall (mm)                        float64
# Direction of maximum wind gust        object
# Speed of maximum wind gust (km/h)    float64
# Time of maximum wind gust             object
# 9am Temperature (°C)                 float64
# 9am wind direction                    object
# 9am wind speed (km/h)                 object
# 3pm Temperature (°C)                 float64
# 3pm wind direction                    object
# 3pm wind speed (km/h)                 object
# station_id                             int64
# dtype: object

# %%
# clean date column
clean_Ballarat['Date']= pd.to_datetime(clean_Ballarat['Date'], dayfirst=True)

# %%
clean_Ballarat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 30
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               1300 non-null   datetime64[ns]
#  1   Minimum temperature (°C)           1300 non-null   float64
#  2   Maximum temperature (°C)           1300 non-null   float64
#  3   Rainfall (mm)                      1300 non-null   float64
#  4   Direction of maximum wind gust     1300 non-null   object
#  5   Speed of maximum wind gust (km/h)  1300 non-null   float64
#  6   Time of maximum wind gust          1300 non-null   object
#  7   9am Temperature (°C)               1300 non-null   float64
#  8   9am wind direction                 1300 non-null   object
#  9   9am wind speed (km/h)              1300 non-null   object
#  10  3pm Temperature (°C)               1300 non-null   float64
# ...

# %%
# Change data column types for time and date fields, also for km/h, now 'calm' has been replaced with 0.

clean_Ballarat[["9am wind speed (km/h)", "3pm wind speed (km/h)"]] = clean_Ballarat[["9am wind speed (km/h)", "3pm wind speed (km/h)"]].apply(pd.to_numeric)

# %%
clean_Ballarat.dtypes
# Out:
# Date                                 datetime64[ns]
# Minimum temperature (°C)                    float64
# Maximum temperature (°C)                    float64
# Rainfall (mm)                               float64
# Direction of maximum wind gust               object
# Speed of maximum wind gust (km/h)           float64
# Time of maximum wind gust                    object
# 9am Temperature (°C)                        float64
# 9am wind direction                           object
# 9am wind speed (km/h)                         int64
# 3pm Temperature (°C)                        float64
# 3pm wind direction                           object
# 3pm wind speed (km/h)                         int64
# station_id                                    int64
# dtype: object

# %%
clean_Ballarat.to_csv('clean_Ballarat.csv', sep=',', index=False)

# %%
clean_Ballarat_slim = clean_Ballarat[['Date','Minimum temperature (°C)','Maximum temperature (°C)','Direction of maximum wind gust ','Speed of maximum wind gust (km/h)']].copy()

# %%
clean_Ballarat_slim = clean_Ballarat_slim.rename(columns={"Minimum temperature (°C)":'Ball_Minimum temperature (°C)',"Maximum temperature (°C)":"Ball_Maximum temperature (°C)","Direction of maximum wind gust ":"Ball_Direction of maximum wind gust","Speed of maximum wind gust (km/h)":"Ball_Speed of maximum wind gust (km/h)"})

# %%
clean_Ballarat_slim
# Out:
#          Date  Ball_Minimum temperature (°C)  Ball_Maximum temperature (°C)  \
# 0  2022-07-01                            4.8                            9.5
# 1  2022-07-02                            1.2                           10.0
# 2  2022-07-03                            4.8                           10.2
# 3  2022-07-04                            4.9                           11.5
# 4  2022-07-05                            5.9                           11.9
# ..        ...                            ...                            ...
# 26 2019-01-27                           12.0                           26.2
# 27 2019-01-28                           11.2                           31.7
# 28 2019-01-29                           11.0                           34.0
# 29 2019-01-30                           11.7                           36.7
# 30 2019-01-31                           11.9                           21.2
#
# ...

# %%
clean_Ballarat_slim.dtypes
# Out:
# Date                                      datetime64[ns]
# Ball_Minimum temperature (°C)                    float64
# Ball_Maximum temperature (°C)                    float64
# Ball_Direction of maximum wind gust               object
# Ball_Speed of maximum wind gust (km/h)           float64
# dtype: object

# %%
clean_Ballarat_slim.to_csv('clean_Ballarat_slim.csv', sep=',', index=False)
